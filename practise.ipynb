# %% [markdown]
# ## Single statments

# %%
x = 10
print(x)
name = "Rajesh"
# Out:
# 10

# %%
print(name)
# Out:
# Rajesh

# %% [markdown]
# ## Multiple statments

# %%
x = 10; y = 20; print(x+y)
# Out:
# 30

# %%
a = 45; y= 66; print(x-y)
# Out:
# -56

# %%
a = 66; b= 12; print(a*b)
# Out:
# 792

# %%
x = 99; y= 123; print(x/y)
# Out:
# 0.8048780487804879

# %% [markdown]
# ### Multi line statment

# %%
x = 20 + 90 + \
30 + 80
print(x)
# Out:
# 220

# %%
total = 99 - 88 - \
99 - 88
print(total)
# Out:
# -176

# %%
y = [
99,
88,
77,
]
print(y)
# Out:
# [99, 88, 77]

# %%
result = [
    100 * 50
    -10
    +20
]
print(result)
# Out:
# [5010]

# %% [markdown]
# ## Variables

# %%
name = "Rajesh"
age = 21
marks = 80.5
print(name, age, marks)
# Out:
# Rajesh 21 80.5

# %% [markdown]
# ### Variable assignment

# %%
a = 10
print(a)
# Out:
# 10

# %%
name = "Raj"
print(name)
# Out:
# Raj

# %%
a = 20
b = 20
print(a)
print(b)
# Out:
# 20
# 20

# %%
age = 21
marks = 99
salary = 30000
print (age, marks, salary)
# Out:
# 21 99 30000

# %%
height = 5.9
price = 67.77
temp = 36.7
print(height, price, temp)
# Out:
# 5.9 67.77 36.7

# %%
name = "Rajesh"
city = "hyd"
institue = "Datamites"
print(name, city, institue)
# Out:
# Rajesh hyd Datamites

# %%
intvar = 55
floatvar = 77.9
strvar = "hyderabad"
print(intvar, floatvar, strvar)
# Out:
# 55 77.9 hyderabad

# %% [markdown]
# ## multiple variables

# %%
a, b, c = 100, 200, 300
print(a, b, c)
# Out:
# 100 200 300

# %%
x = y = z = 1000
print(x, y, z)
# Out:
# 1000 1000 1000

# %%
name, city, course = "Raj", "hyderabad", "datascience"
print(name, city, course)
# Out:
# Raj hyderabad datascience

# %%
name = "Rajesh"
age = 22
height = 5.7
print(name, age, height)
# Out:
# Rajesh 22 5.7

# %%
intvar, floatvar, strvar = 10, 99.3, "AI"
print(intvar)
print(floatvar)
print(strvar)
# Out:
# 10
# 99.3
# AI

# %%
a = 100
b = 200
a, b = b,a
print(a)
print(b)
# Out:
# 200
# 100

# %%
a, b, c = 10,20,30
total = a + b + c
print(total)
# Out:
# 60

# %% [markdown]
# ## Datatypes
#
# * integer
# * float
# * boolean
# * string

# %%
# integer
a = 10
print(a)
# Out:
# 10

# %%
age = 21
marks = 99
print(age)
print(marks)
# Out:
# 21
# 99

# %%
x = 99
y = 88
sum = a + b
sub = a - b
mul = a * b
div = a / b
print(sum)
print(sub)
print(mul)
print(div)
# Out:
# 30
# -10
# 200
# 0.5

# %%
a = 20

print(a)
print(type(a))
# Out:
# 20
# <class 'int'>

# %%
import sys

num = 1000

print(num)
print(type(num))
print(sys.getsizeof(num))
# Out:
# 1000
# <class 'int'>
# 28

# %%
import sys

a = 50
b = 25

result = a * b

print(result)
print(type(result))
print(sys.getsizeof(result))
print(isinstance(result, int))
# Out:
# 1250
# <class 'int'>
# 28
# True

# %%
import sys

val = 1000

print(val)
print(type(val))
print(sys.getsizeof(val))
print(isinstance(val, int))
# Out:
# 1000
# <class 'int'>
# 28
# True

# %% [markdown]
# ### Float

# %%
x = 5.4

print(x)
print(type(x))
# Out:
# 5.4
# <class 'float'>

# %%
import sys

price = 99.55

print(price)
print(type(price))
print(sys.getsizeof(price))
# Out:
# 99.55
# <class 'float'>
# 24

# %%
import sys 

a = 10.3
b = 9.5

division = a/b

print(division)
print(type(division))
print(sys.getsizeof(division))
print(isinstance(division, float))
# Out:
# 1.0842105263157895
# <class 'float'>
# 24
# True

# %%
import sys

val = 98.77

print(val)
print(type(val))
print(sys.getsizeof(val))
print(isinstance(val, float))
# Out:
# 98.77
# <class 'float'>
# 24
# True

# %% [markdown]
# ### Complex

# %%
num = 2+ 3j

print(num)
print(type(num))
# Out:
# (2+3j)
# <class 'complex'>

# %%
import sys

val = 25 + 55j

print(val)
print(type(val))
print(sys.getsizeof(val, complex))
# Out:
# (25+55j)
# <class 'complex'>
# 32

# %%
import sys

a = 22 + 10j
b = 3 + 55j

result = a + b

print(result)
print(type(result))
print(sys.getsizeof(result))
print(isinstance(result, complex))
# Out:
# (25+65j)
# <class 'complex'>
# 32
# True

# %% [markdown]
# ### Boolean

# %%
a = True

print(a)
print(type(a))
# Out:
# True
# <class 'bool'>

# %%
import sys

status = False

print(status)
print(type(status))
print(sys.getsizeof(status))
# Out:
# False
# <class 'bool'>
# 28

# %%
import sys

a = 20
b = 34

result = a < b
print(result)
print(type(result))
print(sys.getsizeof(result))
print(isinstance(result, bool))
# Out:
# True
# <class 'bool'>
# 28
# True

# %% [markdown]
# ### String

# %%
name = "Rajesh"

print(name)
print(type(name))
# Out:
# Rajesh
# <class 'str'>

# %%
import sys

city = "hyderabad"

print(city)
print(type(city))
print(sys.getsizeof(city))
# Out:
# hyderabad
# <class 'str'>
# 50

# %%
import sys

first = "gonugunta"
last = "Rajesh"

full = first + "" + last
print(full)
print(type(full))
print(sys.getsizeof(full))
print(isinstance(full, str))
# Out:
# gonuguntaRajesh
# <class 'str'>
# 56
# True

# %% [markdown]
# ### String indexing

# %%
name = "python"

print(name[2])
print(name[5])
print(name[0])
# Out:
# t
# n
# p

# %%
word = "Rajesh"

print(word[0])
print(word[5])
# Out:
# R
# h

# %%
str = "Data Science"

print(str[-3])
print(str[-1])
print(str[-2])
# Out:
# n
# e
# c

# %%
city = "ongole"

print(city[11])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[41], line 3
#       1 city = "ongole"
# ----> 3 print(city[11])
#
# IndexError: string index out of range

# %%
word = "DATA SCIENCE"

for i in range(len(word)):
    print(i, word[i])
# Out:
# 0 D
# 1 A
# 2 T
# 3 A
# 4
# 5 S
# 6 C
# 7 I
# 8 E
# 9 N
# 10 C
# 11 E

# %%
name = "vizag"

print(len(name))
# Out:
# 5

# %% [markdown]
# ## Slicing
#
# * string[start : stop : step]

# %%
text = "python"

print(text[0:5])
# Out:
# pytho

# %%
name = "Rajesh"

print(name[:2])
# Out:
# Ra

# %%
course = "python"

print(course[1:])
# Out:
# ython

# %%
word = "programming"

print(word[::])
# Out:
# programming

# %%
text = "Data Science" 

print(text[-8:-3])
# Out:
#  Scie

# %%
text = "programmer"

print(text[0:8:3])
# Out:
# pgm

# %% [markdown]
# ### Reverse string

# %%
word = "python"

print(word[::-1])
# Out:
# nohtyp

# %%
city = "hyderabad"

start = 3
stop = 9

print(city[start:stop])
# Out:
# erabad

# %% [markdown]
# ## Update String

# %%
name = "python"
name = "java"

print(name)
# Out:
# java

# %%
text = "python"
new_text = "j" + text[1:]
print(new_text)
# Out:
# jython

# %%
word = "hello"
new_word = word[:1] + "a" + word [2:]

print(new_word)
# Out:
# hallo

# %%
city = "hyderabad"

new_city = city.replace("h", "j")

print(new_city)
# Out:
# jyderabad

# %%
str = "i like to ice cream"
str1 = str.replace ("like", "love")

print(str)

print(str1)
# Out:
# i like to ice cream
# i love to ice cream

# %%
del (str1)

# %%
name = "python"
del name

# %%
name = "python"
del name

print(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 name = "python"
#       2 del name
# ----> 4 print(name)
#
# NameError: name 'name' is not defined

# %%
name = "rajesh"
update = name.replace("rajesh", "suresh")
print(update)
# Out:
# suresh

# %% [markdown]
# ### String concatenation

# %%
a = "hello"
b = "world"

print(a+b)
# Out:
# helloworld

# %%
first = "Hello"
second = "World"

print(first + " " + second)
# Out:
# Hello World

# %%
name = "rajesh"
city = "hyderabad"
course = "ai"

print(name + " from " + city + " learning " + course)
# Out:
# rajesh from hyderabad learning ai

# %%
text = "python"
text += " program"
print(text)
# Out:
# python program

# %%
words = ["python", "is", "easy"]
result = " ".join(words)
print(result)
# Out:
# python is easy

# %% [markdown]
# ## String Membership

# %%
text = "python"
print("p" in text)
# Out:
# True

# %%
sentence = "i am learning in python"
print("python" in sentence)
# Out:
# True

# %%
text = "python"
print("java" not in text)
# Out:
# True

# %%
name = "rajesh"
char = "e"
print(char in name)
# Out:
# True

# %%
course = "python program"
if "python" in course:
    print("python found")
else:
    print("python not found")
# Out:
# python found

# %%
text = "Data Science"
print("Data" in text)
# Out:
# True

# %%
text = "python"
print("Python" in text)
# Out:
# False

# %%
name = "rajesh"
print("z" not in name)
# Out:
# True

# %% [markdown]
# ## String Partitioning
#
# *splits into 3 parts
#
# * before seprator
# * seprator
# * after seprator
# * string.partition(seprator)

# %%
text = "python-java"
print(text.partition("-"))
# Out:
# ('python', '-', 'java')

# %%
name = "Rajesh kumar"
print(name.partition(" "))
# Out:
# ('Rajesh', ' ', 'kumar')

# %%
email = "gonuguntarajesh99999@gmail.com"
result = email.partition("@")
print(result)
# Out:
# ('gonuguntarajesh99999', '@', 'gmail.com')

# %%
text = ("python-programming")
a, b, c = text.partition("-")
print(a, b, c)
# Out:
# python - programming

# %%
text = python
print(text.partition("-"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 text = python
#       2 print(text.partition("-"))
#
# NameError: name 'python' is not defined

# %%
text = "a-b-c"
print(text.rpartition("-"))
# Out:
# ('a-b', '-', 'c')

# %%
date = "2026/05/15"
print(date.partition("/"))
# Out:
# ('2026', '/', '05/15')

# %% [markdown]
# ## String Functions

# %%
#length

text = "Data Science"
print(len(text))
# Out:
# 12

# %%
# Upper()

name = "ai engineer"
print(name.upper())
# Out:
# AI ENGINEER

# %%
# Lower()

word = "ARTIFICAL Intellegence"

print(word.lower())
# Out:
# artifical intellegence

# %%
# title()

name = "python programming"
print(name.title())
# Out:
# Python Programming

# %%
# Capitalize

word = "happy days"
print(word.capitalize())
# Out:
# Happy days

# %%
# Strip (remove spaces)

text ="  python   "
print(text.strip())
# Out:
# python

# %%
# Replace() 

text = "Hello World"
print(text.replace("World", "python"))
# Out:
# Hello python

# %%
# split()

city ="hyderabad banglore chennai"
print(city.split())
# Out:
# ['hyderabad', 'banglore', 'chennai']

# %%
# join()

words = ["kerala", "pune", "vizag"]
print("-".join(words))
# Out:
# kerala-pune-vizag

# %%
# find()

text = "Data Science"
print(text.find("t"))
# Out:
# 2

# %%
# count()

text = "programmer"
print(text.count("m"))
# Out:
# 2

# %%
# startswith()

word = "delhi capitals"
print(word.startswith("de"))
# Out:
# True

# %%
# endswith()

text = "orange army"
print(text.endswith("army"))
# Out:
# True

# %%
# isalphaa()

text = "python"
print(text.isalpha())
# Out:
# True

# %%
# isdigit()

num = "998877"
print(num.isdigit())
# Out:
# True

# %%
# format{}

name = "rajesh"
age = 21

print("my name is {} and age is {}".format(name, age))
# Out:
# my name is rajesh and age is 21

# %% [markdown]
# ## Typecasting
#
# * int()
# * float()
# * str()
# * bool()

# %%
# int()

x = 10.5
y = int(x)

print(y)
# Out:
# 10

# %%
num = "99"
print(int(num))
# Out:
# 99

# %%
# float()

a = 10.99
b = float(a)
print(a)
# Out:
# 10.99

# %%
price = "100"
print(float(price))
# Out:
# 100.0

# %%
# str()

age = 21
print(str(age))
# Out:
# 21

# %%
age = 22
print("Age is " + str(age))
# Out:
# Age is 22

# %%
# bool()

print(bool(1))
print(bool(0))
# Out:
# True
# False

# %%
print(bool("python"))
print(bool(""))
# Out:
# True
# False

# %%
a = int(input("Enter the first number: "))
b = int(input("Enter the second number: "))

print(a+b)
# Out:
# Enter the first number:  55
# Enter the second number:  88
# 143

# %%
x = "python"

print(str(x))
# Out:
# python

# %% [markdown]
# ## If condtion

# %%
age = 20
if age >= 18:
    print("Eligible to vote")
# Out:
# Eligible to vote

# %%
# number check

num = 10
if num> 0:
    print("positive number")
# Out:
# positive number

# %%
# string condition

name = "Rajesh"
if name == "Rajesh":
    print("welcome Rajesh")
# Out:
# welcome Rajesh

# %%
# using boolean

is_logged_in = True
if is_logged_in:
    print("login successful")
# Out:
# login successful

# %% [markdown]
# ## IF else

# %%
age = 16
if age >= 18:
    print("Eligible to vote")
else:
    print("not Eligible to vote")
# Out:
# not Eligible to vote

# %%
num = 7
if num % 2 == 0:
    print("even number")
else:
    print("odd number")
# Out:
# odd number

# %%
number = -5
if number > 0:
    print("postive number")
else:
    print("negitive number")
# Out:
# negitive number

# %%
password = "r@jesh123"
if password == "r@jesh123":
    print("login success")
else:
    print("login failed")
# Out:
# login success

# %%
balance = 500
if balance >= 100:
    print("withdrwal success")
else:
    print("Insufficent balance")
# Out:
# withdrwal success

# %%
a = 20
b = 15
if a > b:
    print("bigger")
else:
    print("smaller")
# Out:
# bigger

# %%
marks = 55
if marks >= 50:
    print("pass")
else:
    print("fail")
# Out:
# pass
